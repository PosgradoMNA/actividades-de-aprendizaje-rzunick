# %% [markdown]
# <a href="https://colab.research.google.com/github/PosgradoMNA/actividades-de-aprendizaje-rzunick/blob/main/Semana_3_Actividad_1_Ronald_Zuniga_A01686240.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Semana 3 - Actividad 1: Practica Bases de Datos**
#
# Nombre: Ronald Zuniga
#
# Matrícula: A01686240

# %% [markdown]
# # Parte 1: Fundamentos de bases de datos

# %% [markdown]
# **Parte 1: Fundamentos de bases de datos**
#
# **Fundamentos de bases de datos para ciencia de datos.**
#
# Uno de los aprendizajes clave de la documentación consultada radica en el entendimiento del proceso general de organización de datos y su terminología clave para comprender la estructura en la cual fue almacenada. El proceso de identificar las fuentes de datos de la organización, o del tema sujeto de estudio para el proyecto, como primer paso desde fuentes formales como bases de datos estructuradas, hasta datos específicos obtenidos por esfuerzos de levantamiento de información o consulta a fuentes externas por medio de APIs.
# El siguiente paso indica entender la estructura de la base de datos y los diferentes atributos e información almacenada. Un aprendizaje clave adicional se identifica en las diferentes maneras existentes para nombrar los componentes de bases de datos: filas y columnas como terminología general entendiendo que entre aplicaciones se les pueden nombrar de diferente manera, filas (records, instancia, punto de datos / datapoint) y columnas (atributos, campos, feature, variable de entrada).
#
# **Fundamentos de almacenes de datos (Data Warehouse) para ciencia de datos.**
#
# El concepto de almacenes de datos se comprende fácilmente con la arquitectura de la casa del lago de Amazon Redshift como parte de sus servicios Amazon Web Services. La analogía de una casa en el lago hace referencia a una arquitectura moderna donde el “lago” representa uno o varios repositorios de datos estructurados, semiestructurados, y no estructurados de los cuales se utilizarán para análisis en proyectos de ciencia de datos.
# Los ingenieros de datos exploran la información contenida en el “lago” de datos para seleccionar y preparar los datos que serán utilizados para el desarrollo de los proyectos. Una vez seleccionados y preparados, los datos se mueven (se crean copias) a almacenes de datos (Data Warehouses) para su análisis y creación de modelos.

# %% [markdown]
# # Parte 2: Selección y limpieza de los Datos en Python

# %%
# Crear variable interna para almacenar base de datos 
input = "https://raw.githubusercontent.com/PosgradoMNA/Actividades_Aprendizaje-/main/default%20of%20credit%20card%20clients.csv"

# %% [markdown]
# **Información sobre la base de datos**
#
# Attribute Information:
#
# This research employed a binary variable, default payment (Yes = 1, No = 0), as the response variable. This study reviewed the literature and used the following 23 variables as explanatory variables:
# * X1: Amount of the given credit (NT dollar): it includes both the individual consumer credit and his/her family (supplementary) credit.
# * X2: Gender (1 = male; 2 = female).
# * X3: Education (1 = graduate school; 2 = university; 3 = high school; 4 = others).
# * X4: Marital status (1 = married; 2 = single; 3 = others).
# * X5: Age (year).
# * X6 - X11: History of past payment. We tracked the past monthly payment records (from April to September, 2005) as follows:
#
# * X6 = the repayment status in September, 2005;
# * X7 = the repayment status in August, 2005; . . .;
# * X11 = the repayment status in April, 2005. The measurement scale for the repayment status is: -1 = pay duly; 1 = payment delay for one month; 2 = payment delay for two months; . . .; 8 = payment delay for eight months; 9 = payment delay for nine months and above.
# * X12-X17: Amount of bill statement (NT dollar). X12 = amount of bill statement in September, 2005;
# * X13 = amount of bill statement in August, 2005; . . .;
# * X17 = amount of bill statement in April, 2005.
# * X18-X23: Amount of previous payment (NT dollar).
# * X18 = amount paid in September, 2005;
# * X19 = amount paid in August, 2005; . . .;
# * X23 = amount paid in April, 2005.

# %%
# Importación de librerias y creación de variable interna para almacenar los datos.
import pandas as pd
import numpy as np
data = pd.read_csv(input)
data
# Out:
#           ID      X1   X2   X3   X4    X5   X6   X7   X8   X9  ...      X15  \
# 0          1   20000  2.0  2.0  1.0  24.0  2.0  2.0 -1.0 -1.0  ...      0.0
# 1          2  120000  2.0  2.0  2.0  26.0 -1.0  2.0  0.0  0.0  ...   3272.0
# 2          3   90000  2.0  2.0  2.0  34.0  0.0  0.0  0.0  0.0  ...  14331.0
# 3          4   50000  2.0  2.0  1.0  37.0  0.0  0.0  0.0  0.0  ...  28314.0
# 4          5   50000  1.0  2.0  1.0  57.0 -1.0  0.0 -1.0  0.0  ...  20940.0
# ...      ...     ...  ...  ...  ...   ...  ...  ...  ...  ...  ...      ...
# 29995  29996  220000  1.0  3.0  1.0  39.0  0.0  0.0  0.0  0.0  ...  88004.0
# 29996  29997  150000  1.0  3.0  2.0  43.0 -1.0 -1.0 -1.0 -1.0  ...   8979.0
# 29997  29998   30000  1.0  2.0  2.0  37.0  4.0  3.0  2.0 -1.0  ...  20878.0
# 29998  29999   80000  1.0  3.0  1.0  41.0  1.0 -1.0  0.0  0.0  ...  52774.0
# 29999  30000   50000  1.0  2.0  1.0  46.0  0.0  0.0  0.0  0.0  ...  36535.0
#
# ...

# %%
#Creación de archivo backup interno.
data.to_csv('data.csv')

# %%
#Verificación de datos faltantes
data.isnull().values.any()
# Out:
# True

# %%
#Verificación de datos faltantes por fila.
data.isnull().any()
# Out:
# ID     False
# X1     False
# X2      True
# X3      True
# X4      True
# X5      True
# X6      True
# X7      True
# X8      True
# X9      True
# X10     True
# X11     True
# X12     True
# X13     True
# X14     True
# X15     True
# X16     True
# X17     True
# X18     True
# X19     True
# X20     True
# X21     True
# X22     True
# X23     True
# Y       True
# dtype: bool

# %%
#Solución 1 - Eliminar todos los renglones, si tienen al menos un dato perdido
ndata = data.dropna()
ndata
# Out:
#           ID      X1   X2   X3   X4    X5   X6   X7   X8   X9  ...      X15  \
# 0          1   20000  2.0  2.0  1.0  24.0  2.0  2.0 -1.0 -1.0  ...      0.0
# 1          2  120000  2.0  2.0  2.0  26.0 -1.0  2.0  0.0  0.0  ...   3272.0
# 2          3   90000  2.0  2.0  2.0  34.0  0.0  0.0  0.0  0.0  ...  14331.0
# 3          4   50000  2.0  2.0  1.0  37.0  0.0  0.0  0.0  0.0  ...  28314.0
# 4          5   50000  1.0  2.0  1.0  57.0 -1.0  0.0 -1.0  0.0  ...  20940.0
# ...      ...     ...  ...  ...  ...   ...  ...  ...  ...  ...  ...      ...
# 29995  29996  220000  1.0  3.0  1.0  39.0  0.0  0.0  0.0  0.0  ...  88004.0
# 29996  29997  150000  1.0  3.0  2.0  43.0 -1.0 -1.0 -1.0 -1.0  ...   8979.0
# 29997  29998   30000  1.0  2.0  2.0  37.0  4.0  3.0  2.0 -1.0  ...  20878.0
# 29998  29999   80000  1.0  3.0  1.0  41.0  1.0 -1.0  0.0  0.0  ...  52774.0
# 29999  30000   50000  1.0  2.0  1.0  46.0  0.0  0.0  0.0  0.0  ...  36535.0
#
# ...

# %%
#Validación de eliminación de renglones con datos perdidos.
ndata.isna().values.any()
# Out:
# False

# %%
#Solución 2 - Eliminar columna, si tienen al menos un dato perdido en una columna.
ndf = data.copy()
ndf.dropna(inplace = True,
           axis = 1
           )
ndf
# Out:
#           ID      X1
# 0          1   20000
# 1          2  120000
# 2          3   90000
# 3          4   50000
# 4          5   50000
# ...      ...     ...
# 29995  29996  220000
# 29996  29997  150000
# 29997  29998   30000
# 29998  29999   80000
# 29999  30000   50000
#
# [30000 rows x 2 columns]

# %%
# Eliminación de filas con al menos 2 valores que no sean nan
ndf = data.copy()
ndf.dropna(thresh=24, inplace = True) #En cada fila validará que existan al menos 24 valores no vacíos
ndf
# Out:
#           ID      X1   X2   X3   X4    X5   X6   X7   X8   X9  ...      X15  \
# 0          1   20000  2.0  2.0  1.0  24.0  2.0  2.0 -1.0 -1.0  ...      0.0
# 1          2  120000  2.0  2.0  2.0  26.0 -1.0  2.0  0.0  0.0  ...   3272.0
# 2          3   90000  2.0  2.0  2.0  34.0  0.0  0.0  0.0  0.0  ...  14331.0
# 3          4   50000  2.0  2.0  1.0  37.0  0.0  0.0  0.0  0.0  ...  28314.0
# 4          5   50000  1.0  2.0  1.0  57.0 -1.0  0.0 -1.0  0.0  ...  20940.0
# ...      ...     ...  ...  ...  ...   ...  ...  ...  ...  ...  ...      ...
# 29995  29996  220000  1.0  3.0  1.0  39.0  0.0  0.0  0.0  0.0  ...  88004.0
# 29996  29997  150000  1.0  3.0  2.0  43.0 -1.0 -1.0 -1.0 -1.0  ...   8979.0
# 29997  29998   30000  1.0  2.0  2.0  37.0  4.0  3.0  2.0 -1.0  ...  20878.0
# 29998  29999   80000  1.0  3.0  1.0  41.0  1.0 -1.0  0.0  0.0  ...  52774.0
# 29999  30000   50000  1.0  2.0  1.0  46.0  0.0  0.0  0.0  0.0  ...  36535.0
#
# ...

# %%
#Solución 2.2 normalización por imputación media
ndf = data.copy()
wm = ndf.X1.mean()
wm
# Out:
# 167484.32266666667

# %%
ndf['X1'].fillna(value = wm, inplace = True)
ndf
# Out:
#           ID      X1   X2   X3   X4    X5   X6   X7   X8   X9  ...      X15  \
# 0          1   20000  2.0  2.0  1.0  24.0  2.0  2.0 -1.0 -1.0  ...      0.0
# 1          2  120000  2.0  2.0  2.0  26.0 -1.0  2.0  0.0  0.0  ...   3272.0
# 2          3   90000  2.0  2.0  2.0  34.0  0.0  0.0  0.0  0.0  ...  14331.0
# 3          4   50000  2.0  2.0  1.0  37.0  0.0  0.0  0.0  0.0  ...  28314.0
# 4          5   50000  1.0  2.0  1.0  57.0 -1.0  0.0 -1.0  0.0  ...  20940.0
# ...      ...     ...  ...  ...  ...   ...  ...  ...  ...  ...  ...      ...
# 29995  29996  220000  1.0  3.0  1.0  39.0  0.0  0.0  0.0  0.0  ...  88004.0
# 29996  29997  150000  1.0  3.0  2.0  43.0 -1.0 -1.0 -1.0 -1.0  ...   8979.0
# 29997  29998   30000  1.0  2.0  2.0  37.0  4.0  3.0  2.0 -1.0  ...  20878.0
# 29998  29999   80000  1.0  3.0  1.0  41.0  1.0 -1.0  0.0  0.0  ...  52774.0
# 29999  30000   50000  1.0  2.0  1.0  46.0  0.0  0.0  0.0  0.0  ...  36535.0
#
# ...

# %%
#Solución 3 - Eliminar los renglones si todos los valores son perdidos
ndf = df2.copy()
ndf.dropna(how = "all", 
           inplace = True)
ndf
# Out:
#           ID      X1   X2   X3   X4    X5   X6   X7   X8   X9  ...      X15  \
# 0          1   20000  2.0  2.0  1.0  24.0  2.0  2.0 -1.0 -1.0  ...      0.0
# 1          2  120000  2.0  2.0  2.0  26.0 -1.0  2.0  0.0  0.0  ...   3272.0
# 2          3   90000  2.0  2.0  2.0  34.0  0.0  0.0  0.0  0.0  ...  14331.0
# 3          4   50000  2.0  2.0  1.0  37.0  0.0  0.0  0.0  0.0  ...  28314.0
# 4          5   50000  1.0  2.0  1.0  57.0 -1.0  0.0 -1.0  0.0  ...  20940.0
# ...      ...     ...  ...  ...  ...   ...  ...  ...  ...  ...  ...      ...
# 29995  29996  220000  1.0  3.0  1.0  39.0  0.0  0.0  0.0  0.0  ...  88004.0
# 29996  29997  150000  1.0  3.0  2.0  43.0 -1.0 -1.0 -1.0 -1.0  ...   8979.0
# 29997  29998   30000  1.0  2.0  2.0  37.0  4.0  3.0  2.0 -1.0  ...  20878.0
# 29998  29999   80000  1.0  3.0  1.0  41.0  1.0 -1.0  0.0  0.0  ...  52774.0
# 29999  30000   50000  1.0  2.0  1.0  46.0  0.0  0.0  0.0  0.0  ...  36535.0
#
# ...

# %%
#Solución 4 - Si existe al menos 3 datos, no se eliminará el renglón
ndf = df2.copy()
ndf.dropna(thresh =3, 
           inplace = True,
           )
ndf
# Out:
#           ID      X1   X2   X3   X4    X5   X6   X7   X8   X9  ...      X15  \
# 0          1   20000  2.0  2.0  1.0  24.0  2.0  2.0 -1.0 -1.0  ...      0.0
# 1          2  120000  2.0  2.0  2.0  26.0 -1.0  2.0  0.0  0.0  ...   3272.0
# 2          3   90000  2.0  2.0  2.0  34.0  0.0  0.0  0.0  0.0  ...  14331.0
# 3          4   50000  2.0  2.0  1.0  37.0  0.0  0.0  0.0  0.0  ...  28314.0
# 4          5   50000  1.0  2.0  1.0  57.0 -1.0  0.0 -1.0  0.0  ...  20940.0
# ...      ...     ...  ...  ...  ...   ...  ...  ...  ...  ...  ...      ...
# 29995  29996  220000  1.0  3.0  1.0  39.0  0.0  0.0  0.0  0.0  ...  88004.0
# 29996  29997  150000  1.0  3.0  2.0  43.0 -1.0 -1.0 -1.0 -1.0  ...   8979.0
# 29997  29998   30000  1.0  2.0  2.0  37.0  4.0  3.0  2.0 -1.0  ...  20878.0
# 29998  29999   80000  1.0  3.0  1.0  41.0  1.0 -1.0  0.0  0.0  ...  52774.0
# 29999  30000   50000  1.0  2.0  1.0  46.0  0.0  0.0  0.0  0.0  ...  36535.0
#
# ...

# %% [markdown]
# **Practica Active Class**

# %%
import pandas as pd
import numpy as np

x = {"Company" : ["Ford","Ford","VW","BMW","Cooper","Cooper"], 
     "Stars" : [1, 2, np.nan, 2, 1, 1],
     "Weight" : [2,4,2,2,3, None],
     "Origin" : ["Mexico", "China", "Mexico", None, "China", np.nan],
     "Length" : [50, 40, 30, np.nan, 45, pd.NaT]
}

# %%
df.isnull().values.any()
# Out:
# True

# %%
df.isnull().any()
# Out:
# Company    False
# Stars       True
# Weight      True
# Origin      True
# Length      True
# dtype: bool

# %%
df = pd.DataFrame(data = x)
df
# Out:
#   Company  Stars  Weight  Origin Length
# 0    Ford    1.0     2.0  Mexico     50
# 1    Ford    2.0     4.0   China     40
# 2      VW    NaN     2.0  Mexico     30
# 3     BMW    2.0     2.0    None    NaN
# 4  Cooper    1.0     3.0   China     45
# 5  Cooper    1.0     NaN     NaN    NaT

# %%
#Substituir NA con mean
ndf = df.copy()
ndf["Stars"].fillna(value = ndf["Stars"].mean(),
                    inplace = True
                    )
ndf
# Out:
#   Company  Stars  Weight  Origin Length
# 0    Ford    1.0     2.0  Mexico     50
# 1    Ford    2.0     4.0   China     40
# 2      VW    1.4     2.0  Mexico     30
# 3     BMW    2.0     2.0    None    NaN
# 4  Cooper    1.0     3.0   China     45
# 5  Cooper    1.0     NaN     NaN    NaT

# %%
ndf = df.copy()
sm = ndf["Stars"].median()

ndf["Stars"].fillna(value = sm,
                    inplace = True
                    )
ndf
# Out:
#   Company  Stars  Weight  Origin Length
# 0    Ford    1.0     2.0  Mexico     50
# 1    Ford    2.0     4.0   China     40
# 2      VW    1.0     2.0  Mexico     30
# 3     BMW    2.0     2.0    None    NaN
# 4  Cooper    1.0     3.0   China     45
# 5  Cooper    1.0     NaN     NaN    NaT

# %%
ndf["Origin"].mode()
# Out:
# 0     China
# 1    Mexico
# dtype: object

# %%
oc = ndf["Origin"].mode()[0]

# %%
#Columna Origin se limpian datos perdidos utilizando moda. 
ndf["Origin"].fillna(value = oc,
           inplace = True
           )
ndf
# Out:
#   Company  Stars  Weight  Origin Length
# 0    Ford    1.0     2.0  Mexico     50
# 1    Ford    2.0     4.0   China     40
# 2      VW    1.0     2.0  Mexico     30
# 3     BMW    2.0     2.0   China    NaN
# 4  Cooper    1.0     3.0   China     45
# 5  Cooper    1.0     NaN   China    NaT

# %%
ndf.describe()
# Out:
#           Stars    Weight
# count  6.000000  5.000000
# mean   1.333333  2.600000
# std    0.516398  0.894427
# min    1.000000  2.000000
# 25%    1.000000  2.000000
# 50%    1.000000  2.000000
# 75%    1.750000  3.000000
# max    2.000000  4.000000

# %% [markdown]
# Ejemplos Data Slicing

# %%
x = ndf.Company
x
# Out:
# 0      Ford
# 1      Ford
# 2        VW
# 3       BMW
# 4    Cooper
# 5    Cooper
# Name: Company, dtype: object

# %%
type(x)
# Out:
# pandas.core.series.Series

# %%
y = ndf["Company"]
y
# Out:
# 0      Ford
# 1      Ford
# 2        VW
# 3       BMW
# 4    Cooper
# 5    Cooper
# Name: Company, dtype: object

# %%
type(y)
# Out:
# pandas.core.series.Series

# %%
z = ndf[["Company"]]
z
# Out:
#   Company
# 0    Ford
# 1    Ford
# 2      VW
# 3     BMW
# 4  Cooper
# 5  Cooper

# %%
type(z)
# Out:
# pandas.core.frame.DataFrame

# %%
ndf.columns
# Out:
# Index(['Company', 'Stars', 'Weight', 'Origin', 'Length'], dtype='object')

# %%
ndf[["Company", "Stars"]]
# Out:
#   Company  Stars
# 0    Ford    1.0
# 1    Ford    2.0
# 2      VW    1.0
# 3     BMW    2.0
# 4  Cooper    1.0
# 5  Cooper    1.0

# %%
ndf.loc[1:4, "Stars":"Origin"]
# Out:
#    Stars  Weight  Origin
# 1    2.0     4.0   China
# 2    1.0     2.0  Mexico
# 3    2.0     2.0   China
# 4    1.0     3.0   China

# %%
ndf.iloc[1:5, 1:4]
# Out:
#    Stars  Weight  Origin
# 1    2.0     4.0   China
# 2    1.0     2.0  Mexico
# 3    2.0     2.0   China
# 4    1.0     3.0   China

# %% [markdown]
# # Parte 3: Preparación de los datos

# %% [markdown]
# **Parte 3: Preparación de los datos**
#
# 1.	¿Qué datos considero más importantes? ¿Por qué?
#
# R// Se consideran como los atributos más importantes de la base de datos, las columnas X1 y X3 considerando que el primero representa a la variable meta a optimizar o predecir con el modelo propuesto. El atributo X3, en cambio, se considera como el “driver” social más importante a estudiar para entender si este afecta el comportamiento del consumidor.
#
# 2.	¿Se eliminaron o reemplazaron datos nulos? ¿Qué se hizo y por qué?
#
# R// Si, se realizaron 4 transformaciones incluyendo las soluciones de eliminación selectiva por fila y columna, al igual que el reemplazo de valores por medio de los métodos de interpolación considerando criterios de preservación e integridad de datos de los atributos principales identificados (X1 y X3).
#
# 3.	¿Es necesario ordenar los datos para el análisis? Sí / No / ¿Por qué?
#
# R// Es necesario normalizar y depurar la base de datos previo a la transformación de datos y previo al análisis. El ordenamiento, si se refiere a la clasificación o “sorting” de los datos, no es necesario considerando la cantidad de datos en la BD y considerando las tendencias aleatorias de los datos.
#
# 4.	¿Existen problemas de formato que deban solucionar antes del proceso de modelado? Sí / No / Por qué.
#
# R// Si, específicamente el problema de rangos diferentes de cada columna. Es recomendado normalizar la base de datos colocando toda la información cuantitativa en rangos o categorías similares, de acuerdo al tipo de dato que maneja, para facilitar su procesamiento en las etapas de entrenamiento de modelos.
#
# 5.	¿Qué ajustes se realizaron en el proceso de limpieza de datos (agregar, integrar, eliminar, modificar registros (filas), cambiar atributos (columnas)?
#
# R// Se realizaron 4 soluciones de ajuste y proceso de limpieza de datos incluyendo las soluciones de eliminación selectiva por fila y columna, al igual que el reemplazo de valores por medio de los métodos de interpolación considerando criterios de preservación e integridad de datos de los atributos principales identificados (X1 y X3).
